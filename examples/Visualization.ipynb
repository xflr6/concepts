# %%
# %cd -q ..

import concepts

concepts.__version__
# Out:
# '0.9.3.dev0'

# %%
c = concepts.make_context('''
       |property1|property2|property3|
Object1|    X    |         |    X    |
Object2|         |    X    |         |
Object3|         |    X    |    X    |
Object4|         |    X    |         |
Object5|    X    |    X    |         |
''')

print(c)
# Out:
# <Context object mapping 5 objects to 3 properties [483e8661] at 0x51805b0>
#            |property1|property2|property3|
#     Object1|X        |         |X        |
#     Object2|         |X        |         |
#     Object3|         |X        |X        |
#     Object4|         |X        |         |
#     Object5|X        |X        |         |

# %%
l = c.lattice

l
# Out:
# <Lattice object of 3 atoms 8 concepts 3 coatoms at 0x4ecc700>

# %%
import graphviz

graphviz.version()
# Out:
# (2, 38, 0)

# %%
g = l.graphviz()

g

# %%
g.node_attr = {'shape': 'circle', 'width': '0.2', 'style': 'filled', 'label': ''}
g.edge_attr = {'dir': 'none', 'labeldistance': '1', 'minlen': '1', 'fontsize': '10'}

g

# %%
g.node_attr['color'] = 'yellow'

g

# %%
del g.node_attr['color']
g.edge_attr['fontsize'] = '5'

g

# %%
g.edge_attr.update(fontsize='10', minlen='2')

g
